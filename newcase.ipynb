# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/Minimum Wage Data.csv",encoding = "latin")

# %%
df.to_csv("datasets/minwage.csv", encoding= "utf-8")

# %%
df = pd.read_csv("datasets/minwage.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# 3                               8.55                    1.15
# 4                               8.55                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                 8.55         34.8
# 1                                15.61         34.8
# 2                                 8.55         34.8
# 3                                 8.55         34.8
# 4                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
gb = df.groupby("State")

# %%
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# 1971                               8.30                    1.30
# 1972                               9.90                    1.60
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# Year
# 1968                                 8.55         34.8
# 1969                                 8.11         36.7
# 1970                                 8.67         38.8
# 1971                                 8.30         40.5
# 1972                                 9.90         41.8
#
#      Department.Of.Labor.Uncleaned.Data  \
# Year
# 1968                                ...
# 1969                                ...
# 1970                                ...
# 1971                                ...
# 1972                                ...
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# Year
# 1968                                    0.0
# 1969                                    0.0
# 1970                                    0.0
# 1971                                    0.0
# 1972                                    0.0
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# Year
# 1968                                                0.0
# 1969                                                0.0
# 1970                                                0.0
# 1971                                                0.0
# 1972                                                0.0
#
#       Department.Of.Labor.Cleaned.High.Value  \
# Year
# 1968                                     0.0
# 1969                                     0.0
# 1970                                     0.0
# 1971                                     0.0
# 1972                                     0.0
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# Year
# 1968                                                0.0        NaN
# 1969                                                0.0        NaN
# 1970                                                0.0        NaN
# 1971                                                0.0        NaN
# 1972                                                0.0        NaN

# %%
act_min_wage = pd.DataFrame()

# %%
for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name}))

act_min_wage.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       3         act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name})
#       4     else:
# ----> 5         act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name}))
#       7 act_min_wage.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
#    9734         rsuffix=rsuffix,
#    9735         sort=sort,
#    9736         validate=validate,
#    9737     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9768, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9758     if how == "cross":
#    9759         return merge(
#    9760             self,
#    9761             other,
#    (...)
#    9766             validate=validate,
#    9767         )
# -> 9768     return merge(
#    9769         self,
#    9770         other,
#    9771         left_on=on,
#    9772         how=how,
#    9773         left_index=on is None,
#    9774         right_index=True,
#    9775         suffixes=(lsuffix, rsuffix),
#    9776         sort=sort,
#    9777         validate=validate,
#    9778     )
#    9779 else:
#    9780     if on is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:162, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
#     148     op = _MergeOperation(
#     149         left,
#     150         right,
#    (...)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:811, in _MergeOperation.get_result(self, copy)
#     807     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     809 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 811 result = self._reindex_and_concat(
#     812     join_index, left_indexer, right_indexer, copy=copy
#     813 )
#     814 result = result.__finalize__(self, method=self._merge_type)
#     816 if self.indicator:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:763, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     760 left = self.left[:]
#     761 right = self.right[:]
# --> 763 llabels, rlabels = _items_overlap_with_suffix(
#     764     self.left._info_axis, self.right._info_axis, self.suffixes
#     765 )
#     767 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     768     # Pinning the index here (and in the right code just below) is not
#     769     #  necessary, but makes the `.take` more performant if we have e.g.
#     770     #  a MultiIndex for left.index.
#     771     lmgr = left._mgr.reindex_indexer(
#     772         join_index,
#     773         left_indexer,
#    (...)
#     778         use_na_proxy=True,
#     779     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:2604, in _items_overlap_with_suffix(left, right, suffixes)
#    2601 lsuffix, rsuffix = suffixes
#    2603 if not lsuffix and not rsuffix:
# -> 2604     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2606 def renamer(x, suffix):
#    2607     """
#    2608     Rename the left and right indices.
#    2609
#    (...)
#    2620     x : renamed column name
#    2621     """
#
# ValueError: columns overlap but no suffix specified: Index(['Alabama'], dtype='object')

# %%
act_min_wage,
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   9.917736   2.917358   7.139245    9.101132   6.881698
# std        0.0   1.852213   4.102247   1.459132    1.418712   1.921086
# min        0.0   7.620000   0.000000   1.100000    6.630000   3.970000
# 25%        0.0   8.590000   0.000000   6.780000    8.000000   5.250000
# 50%        0.0   9.260000   0.000000   7.210000    9.010000   6.670000
# 75%        0.0  10.510000   8.290000   7.740000    9.710000   8.430000
# max        0.0  15.610000  12.140000  10.000000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   7.818679              8.919245   2.415283  ...
# std       1.106907   1.307834              1.932959   3.882305  ...
# min       7.040000   4.550000              5.690000   0.000000  ...
# 25%       8.200000   7.320000              7.420000   0.000000  ...
# 50%       9.430000   8.170000              8.840000   0.000000  ...
# 75%       9.870000   8.620000              9.600000   8.210000  ...
# max      11.450000   9.900000             14.160000   8.790000  ...
#
#        Tennessee      Texas  U.S. Virgin Islands       Utah    Vermont  \
# count       53.0  53.000000            42.000000  53.000000  53.000000
# mean         0.0   5.816038             6.980238   7.079245   9.057358
# std          0.0   2.240879             1.815899   0.824707   1.093119
# min          0.0   0.000000             4.430000   4.950000   7.030000
# 25%          0.0   4.990000             5.225000   6.610000   8.060000
# 50%          0.0   6.360000             7.105000   7.220000   9.240000
# 75%          0.0   7.350000             8.270000   7.660000   9.820000
# max          0.0   8.660000            10.620000   8.600000  11.090000
#
#         Virginia  Washington  West Virginia  Wisconsin    Wyoming
# count  53.000000   53.000000      53.000000  53.000000  53.000000
# mean    6.163019    8.826038       7.486226   7.914528   5.313208
# std     2.749633    2.147933       0.866017   0.778113   2.004899
# min     0.000000    4.550000       5.770000   6.630000   2.340000
# 25%     6.250000    7.610000       6.850000   7.320000   3.500000
# 50%     7.210000    9.700000       7.370000   7.810000   5.550000
# 75%     7.810000   10.180000       7.930000   8.340000   6.820000
# max     9.090000   13.660000       9.430000   9.980000   9.280000
#
# [8 rows x 54 columns]

# %%
act_min_wage.corr()
# Out:
#                       Alabama    Alaska   Arizona  Arkansas  California  \
# Alabama                   NaN       NaN       NaN       NaN         NaN
# Alaska                    NaN  1.000000  0.037101 -0.332127    0.622245
# Arizona                   NaN  0.037101  1.000000  0.271834    0.639006
# Arkansas                  NaN -0.332127  0.271834  1.000000    0.030265
# California                NaN  0.622245  0.639006  0.030265    1.000000
# Colorado                  NaN -0.078678  0.820730  0.333597    0.649967
# Connecticut               NaN  0.646909  0.555455  0.183662    0.881831
# Delaware                  NaN  0.260265  0.477781  0.107639    0.518481
# District of Columbia      NaN  0.271810  0.723523  0.433775    0.727373
# Florida                   NaN -0.193062  0.907295  0.340509    0.443946
# Alabama                     NaN       NaN
# Alaska                 0.683108  0.726771
# Arizona                0.014723  0.288171
# Arkansas              -0.069024 -0.235369
# California             0.382444  0.598739
# Colorado              -0.101133  0.095454
# Connecticut            0.468287  0.752009
# Delaware               0.024637  0.484522
# District of Columbia   0.085788  0.328834
# Florida               -0.061231  0.149554
# Georgia               -0.434365 -0.098952
# Guam                   0.726536  0.542144
# Hawaii                 0.467383  0.544010
# Idaho                  0.362122  0.396824
# Illinois              -0.183853 -0.223443
# Indiana                0.237954  0.568333
# Iowa                  -0.452995 -0.303209
# Kansas                -0.201143 -0.430025
# Kentucky              -0.197694 -0.421230
# Louisiana                   NaN       NaN
# Maine                  0.509900  0.451237
# Maryland               0.513456  0.213820
# Massachusetts          0.370725  0.575660
# Michigan               0.719225  0.506710
# Minnesota             -0.007897 -0.642386
# Mississippi                 NaN       NaN
# Missouri              -0.441635 -0.270738
# Montana               -0.242749 -0.310200
# Nebraska              -0.201771  0.012383
# Nevada                 0.763468  0.549069
# New Hampshire          0.890565  0.461103
# New Jersey             0.604300  0.369958
# New Mexico             0.608179  0.423926
# New York               0.543789  0.672775
# North Carolina         0.797673  0.388642
# North Dakota           0.417059 -0.144383
# Ohio                   0.194485 -0.202383
# Oklahoma               0.277606 -0.172678
# Oregon                 0.116662  0.102129
# Pennsylvania           0.907332  0.375716
# Puerto Rico            0.015987  0.375641
# Rhode Island           0.301237  0.630303
# South Carolina              NaN       NaN
# South Dakota          -0.029574 -0.190646
# Tennessee                   NaN       NaN
# Texas                 -0.334920 -0.027358
# U.S. Virgin Islands    0.188345 -0.439579
# Utah                   0.251923  0.005837
# Vermont                0.533349  0.622181
# Virginia              -0.080277 -0.545553
# Washington             0.134650  0.544957
# West Virginia          0.269653  0.087201
# Wisconsin              1.000000  0.407841
# Wyoming                0.407841  1.000000
#
# [54 rows x 54 columns]

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.037101 -0.332127    0.622245 -0.078678
# Arizona         NaN  0.037101  1.000000  0.271834    0.639006  0.820730
# Arkansas        NaN -0.332127  0.271834  1.000000    0.030265  0.333597
# California      NaN  0.622245  0.639006  0.030265    1.000000  0.649967
#
#             Connecticut  Delaware  District of Columbia   Florida  ...  \
# Alabama             NaN       NaN                   NaN       NaN  ...
# Alaska         0.646909  0.260265              0.271810 -0.193062  ...
# Arizona        0.555455  0.477781              0.723523  0.907295  ...
# Arkansas       0.183662  0.107639              0.433775  0.340509  ...
# California     0.881831  0.518481              0.727373  0.443946  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# Alabama           NaN       NaN                  NaN       NaN       NaN
# Alaska            NaN -0.507366             0.305388 -0.017546  0.615675
# Arizona           NaN  0.398732            -0.421255  0.413915  0.624314
# Arkansas          NaN  0.520381             0.080528  0.208586  0.236875
# California        NaN -0.109316            -0.061610  0.367924  0.894617
#
#             Virginia  Washington  West Virginia  Wisconsin   Wyoming
# Alabama          NaN         NaN            NaN        NaN       NaN
# Alaska     -0.593675    0.378141       0.056924   0.683108  0.726771
# Arizona     0.096048    0.691863       0.663311   0.014723  0.288171
# Arkansas    0.572595    0.130825       0.504703  -0.069024 -0.235369
# California -0.216247    0.816087       0.492809   0.382444  0.598739
#
# [5 rows x 54 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# 3                               8.55                    1.15
# 4                               8.55                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                 8.55         34.8
# 1                                15.61         34.8
# 2                                 8.55         34.8
# 3                                 8.55         34.8
# 4                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
issue_df = df[df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars']==0]

# %%
issue_df.head()
# Out:
#     Unnamed: 0  Year     State  State.Minimum.Wage  \
# 0            0  1968   Alabama                 0.0
# 9            9  1968   Florida                 0.0
# 10          10  1968   Georgia                 0.0
# 14          14  1968  Illinois                 0.0
# 16          16  1968      Iowa                 0.0
#
#     State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                               0.0                  1.15
# 9                               0.0                  1.15
# 10                              0.0                  1.15
# 14                              0.0                  1.15
# 16                              0.0                  1.15
#
#     Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                8.55                    1.15
# 9                                8.55                    1.15
# 10                               8.55                    1.15
# 14                               8.55                    1.15
# 16                               8.55                    1.15
#
#     Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                  8.55         34.8
# 9                                  8.55         34.8
# 10                                 8.55         34.8
# 14                                 8.55         34.8
# 16                                 8.55         34.8
#
#    Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                 ...                                    0.0
# 9                                 ...                                    0.0
# 10                                ...                                    0.0
# 14                                ...                                    0.0
# 16                                ...                                    0.0
#
#     Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# 14                                                0.0
# 16                                                0.0
#
#     Department.Of.Labor.Cleaned.High.Value  \
# 0                                      0.0
# 9                                      0.0
# 10                                     0.0
# 14                                     0.0
# 16                                     0.0
#
#     Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                 0.0        NaN
# 9                                                 0.0        NaN
# 10                                                0.0        NaN
# 14                                                0.0        NaN
# 16                                                0.0        NaN

# %%
issue_df["State"].unique
# Out:
# <bound method Series.unique of 0              Alabama
# 9              Florida
# 10             Georgia
# 14            Illinois
# 16                Iowa
#              ...
# 2808           Alabama
# 2827         Louisiana
# 2833       Mississippi
# 2850    South Carolina
# 2852         Tennessee
# Name: State, Length: 415, dtype: object>

# %%
import numpy as np

# %%
act_min_wage.replace(0,np.NaN).dropna(axis = 1).corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.332127    0.622245 -0.078678     0.646909  0.260265
# Arkansas    -0.332127  1.000000    0.030265  0.333597     0.183662  0.107639
# California   0.622245  0.030265    1.000000  0.649967     0.881831  0.518481
# Colorado    -0.078678  0.333597    0.649967  1.000000     0.520931  0.581162
# Connecticut  0.646909  0.183662    0.881831  0.520931     1.000000  0.586472
#
#              District of Columbia      Guam    Hawaii     Idaho  ...  \
# Alaska                   0.271810  0.787515  0.630212  0.371745  ...
# Arkansas                 0.433775  0.037006  0.324870  0.008276  ...
# California               0.727373  0.411729  0.610784  0.542006  ...
# Colorado                 0.798145 -0.152291  0.291995  0.436981  ...
# Connecticut              0.700081  0.587469  0.674581  0.536894  ...
#
#                Oregon  Pennsylvania  Rhode Island  South Dakota      Utah  \
# Alaska       0.010495      0.590298      0.610099     -0.287259 -0.017546
# Arkansas     0.399650      0.065998      0.160773      0.826094  0.208586
# California   0.572160      0.241669      0.816544      0.171242  0.367924
# Colorado     0.733803     -0.229508      0.559646      0.519677  0.538775
# Connecticut  0.480491      0.408964      0.829952      0.228521  0.307922
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.615675    0.378141       0.056924   0.683108  0.726771
# Arkansas     0.236875    0.130825       0.504703  -0.069024 -0.235369
# California   0.894617    0.816087       0.492809   0.382444  0.598739
# Colorado     0.581318    0.721208       0.623479  -0.101133  0.095454
# Connecticut  0.911003    0.760697       0.484080   0.468287  0.752009
#
# [5 rows x 37 columns]

# %%
min_wage_corr = act_min_wage.replace(0,np.NaN).dropna(axis = 1).corr().head()
for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("data missing?")

# %%
grouped_issues = issue_df.groupby("State")
grouped_issues.get_group("Alabama").head(3)
# Out:
#      Unnamed: 0  Year    State  State.Minimum.Wage  \
# 0             0  1968  Alabama                 0.0
# 54           54  1969  Alabama                 0.0
# 108         108  1970  Alabama                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.0                  1.15
# 54                               0.0                  1.15
# 108                              0.0                  1.30
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                 8.55                    1.15
# 54                                8.11                    1.15
# 108                               8.67                    1.30
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                   8.55         34.8
# 54                                  8.11         36.7
# 108                                 8.67         38.8
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                  ...                                    0.0
# 54                                 ...                                    0.0
# 108                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.0
# 54                                                 0.0
# 108                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 0                                       0.0
# 54                                      0.0
# 108                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.0        NaN
# 54                                                 0.0        NaN
# 108                                                0.0        NaN

# %%
for state, data in grouped_issues:
    if data["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"].sum()!= 0.0:
        print("bogus")
